# %%
pip install xlrd
# Out:
# ...
#      |████████████████████████████████| 103 kB 5.4 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import xlrd

# %%
transactions = pd.read_excel('transactions_table.xlsx')
transactions.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
transactions.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
transactions['online_order'].value_counts()
# Out:
# 1.0    9829
# 0.0    9811
# Name: online_order, dtype: int64

# %%
transactions['online_order']=transactions['online_order'].fillna(method='ffill')

# %%
transactions['online_order'].value_counts()
# Out:
# 1.0    10016
# 0.0     9984
# Name: online_order, dtype: int64

# %%
transactions['brand'].value_counts()
# Out:
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: brand, dtype: int64

# %%
transactions['brand']=transactions['brand'].fillna(method='ffill')

# %%
transactions['brand'].value_counts()
# Out:
# Solex             4300
# Giant Bicycles    3344
# WeareA2B          3331
# OHM Cycles        3072
# Trek Bicycles     3016
# Norco Bicycles    2937
# Name: brand, dtype: int64

# %%
transactions['product_line'].value_counts()
# Out:
# Standard    14176
# Road         3970
# Touring      1234
# Mountain      423
# Name: product_line, dtype: int64

# %%
transactions['product_line'] = transactions['product_line'].fillna(method='bfill')

# %%
transactions['product_line'].value_counts()
# Out:
# Standard    14308
# Road         4014
# Touring      1250
# Mountain      428
# Name: product_line, dtype: int64

# %%
transactions['product_class'].value_counts()
# Out:
# medium    13826
# high       3013
# low        2964
# Name: product_class, dtype: int64

# %%
transactions['product_class']=transactions['product_class'].fillna(method='bfill')

# %%
transactions['product_class'].value_counts()
# Out:
# medium    13959
# high       3038
# low        3003
# Name: product_class, dtype: int64

# %%
transactions['product_size'].value_counts()
# Out:
# medium    12990
# large      3976
# small      2837
# Name: product_size, dtype: int64

# %%
transactions['product_size']=transactions['product_size'].fillna(method='ffill')

# %%
transactions['product_size'].value_counts()
# Out:
# medium    13115
# large      4022
# small      2863
# Name: product_size, dtype: int64

# %%
transactions['standard_cost'].mean()
# Out:
# 556.0469512209312

# %%
transactions['standard_cost']=transactions['standard_cost'].fillna(transactions['standard_cost'].mean())

# %%
transactions['standard_cost'].mean()
# Out:
# 556.0469512209311

# %%
transactions['product_first_sold_date']=transactions['product_first_sold_date'].fillna(transactions['product_first_sold_date'].mean())

# %%
final_transactions = pd.DataFrame({
        "transaction_id": train["transaction_id"],
        "product_id": train["product_id"],
        "customer_id": train["customer_id"],
        "transaction_date": train["transaction_date"],
        "online_order": train["online_order"],
        "order_status": train["order_status"],
        "brand": train["brand"],
        "product_line": train["product_line"],
        "product_class": train["product_class"],
        "product_size": train["product_size"],
        "list_price": train["list_price"],
        "standard_cost": train["standard_cost"],
        "product_first_sold_date": train["product_first_sold_date"]
    })

# %%
final_transactions.to_csv('./final_transactions.csv', index=False)

# %%
print(final_transactions.head(10))
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
# 5               6          25         2339       2017-03-08           1.0
# 6               7          22         1542       2017-04-21           1.0
# 7               8          15         2459       2017-07-15           0.0
# 8               9          67         1305       2017-08-10           0.0
# 9              10          12         3262       2017-08-30           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# ...

# %%
final_transactions.shape
# Out:
# (20000, 13)
